# %%
import pandas as pd
import numpy as np #pandas is built on top of numpy. numpy used as a DA/computation tool
import matplotlib.pyplot as plt
import seaborn as sns

# %%
pd.set_option('display.max_rows', None, 'display.max_colwidth', None)

# %%
pd.set_option('display.max_columns', None, 'display.max_colwidth', None)

# %%
sat19_ca_df = pd.read_csv('/Users/edwardmendoza/Documents/GA/project_1/data/sat_2019_ca.csv')

# %%
sat19_ca_df.head()
# Out:
#             CDS  CCode     CDCode      SCode RType                    SName  \
# 0  6.615981e+12    6.0   661598.0   630046.0     S  Colusa Alternative Home
# 1  6.616061e+12    6.0   661606.0   634758.0     S          Maxwell Sr High
# 2  1.964733e+13   19.0  1964733.0  1930924.0     S      Belmont Senior High
# 3  1.964733e+13   19.0  1964733.0  1931476.0     S  Canoga Park Senior High
# 4  1.964733e+13   19.0  1964733.0  1931856.0     S     Whitman Continuation
#
#                  DName        CName  Enroll12  NumTSTTakr12  ...  \
# 0       Colusa Unified       Colusa      18.0           0.0  ...
# 1      Maxwell Unified       Colusa      29.0          10.0  ...
# 2  Los Angeles Unified  Los Angeles     206.0         102.0  ...
# 3  Los Angeles Unified  Los Angeles     227.0         113.0  ...
# 4  Los Angeles Unified  Los Angeles      18.0          14.0  ...
#
#   NumERWBenchmark11 PctERWBenchmark11 NumMathBenchmark11 PctMathBenchmark11  \
# ...

# %%
sat19_ca_df.head()
# Out:
#             CDS  CCode     CDCode      SCode RType                    SName  \
# 0  6.615981e+12    6.0   661598.0   630046.0     S  Colusa Alternative Home
# 1  6.616061e+12    6.0   661606.0   634758.0     S          Maxwell Sr High
# 2  1.964733e+13   19.0  1964733.0  1930924.0     S      Belmont Senior High
# 3  1.964733e+13   19.0  1964733.0  1931476.0     S  Canoga Park Senior High
# 4  1.964733e+13   19.0  1964733.0  1931856.0     S     Whitman Continuation
#
#                  DName        CName  Enroll12  NumTSTTakr12  ... NumTSTTakr11  \
# 0       Colusa Unified       Colusa      18.0           0.0  ...          0.0
# 1      Maxwell Unified       Colusa      29.0          10.0  ...          6.0
# 2  Los Angeles Unified  Los Angeles     206.0         102.0  ...        174.0
# 3  Los Angeles Unified  Los Angeles     227.0         113.0  ...        275.0
# 4  Los Angeles Unified  Los Angeles      18.0          14.0  ...          5.0
#
# ...

# %%
sat19_ca_df.drop(columns = 'Unnamed: 25', inplace = True)

# %%
sat19_ca_df.dropna()
# Out:
#                CDS  CCode     CDCode      SCode RType  \
# 1     6.616061e+12    6.0   661606.0   634758.0     S
# 2     1.964733e+13   19.0  1964733.0  1930924.0     S
# 3     1.964733e+13   19.0  1964733.0  1931476.0     S
# 4     1.964733e+13   19.0  1964733.0  1931856.0     S
# 5     1.964734e+13   19.0  1964733.0  6061451.0     S
# ...            ...    ...        ...        ...   ...
# 1977  2.373866e+13   23.0  2373866.0  2330041.0     S
# 1978  2.373916e+13   23.0  2373916.0  2332260.0     S
# 1979  3.367033e+13   33.0  3367033.0   110627.0     S
# 1980  5.075550e+13   50.0  5075549.0  5032651.0     S
# 2036  0.000000e+00    0.0        0.0        0.0     X
#
#                         SName                            DName  \
# 1             Maxwell Sr High                  Maxwell Unified
# 2         Belmont Senior High              Los Angeles Unified
# 3     Canoga Park Senior High              Los Angeles Unified
# ...

# %%
sat19_ca_df.isnull().sum()
# Out:
# CDS                        1
# CCode                      1
# CDCode                     1
# SCode                      1
# RType                      1
# SName                    598
# DName                     59
# CName                      1
# Enroll12                   1
# NumTSTTakr12               1
# NumERWBenchmark12        276
# PctERWBenchmark12        276
# NumMathBenchmark12       276
# PctMathBenchmark12       276
# Enroll11                   1
# NumTSTTakr11               1
# NumERWBenchmark11        311
# PctERWBenchmark11        311
# NumMathBenchmark11       311
# PctMathBenchmark11       311
# TotNumBothBenchmark12    276
# PctBothBenchmark12       276
# TotNumBothBenchmark11    311
# PctBothBenchmark11       311
# Year                       1
# dtype: int64

# %%
sat19_ca_df = sat19_ca_df.replace("*", np.nan)

# %%
sat19_ca_df.tail()
# Out:
#                CDS  CCode     CDCode  SCode RType SName                DName  \
# 2575  5.772678e+13   57.0  5772678.0    0.0     D   NaN  Davis Joint Unified
# 2576  7.000000e+12    7.0   700000.0    0.0     C   NaN                  NaN
# 2577  1.700000e+13   17.0  1700000.0    0.0     C   NaN                  NaN
# 2578  3.800000e+13   38.0  3800000.0    0.0     C   NaN                  NaN
# 2579           NaN    NaN        NaN    NaN   NaN   NaN                  NaN
#
#               CName  Enroll12  NumTSTTakr12  ... NumTSTTakr11  \
# 2575           Yolo     717.0         307.0  ...        474.0
# 2576   Contra Costa   14593.0        5412.0  ...       5157.0
# 2577           Lake     667.0         167.0  ...        126.0
# 2578  San Francisco    4447.0        2256.0  ...       2042.0
# 2579            NaN       NaN           NaN  ...          NaN
#
#      NumERWBenchmark11 PctERWBenchmark11 NumMathBenchmark11  \
# 2575               454             95.78                428
# ...

# %%
sat19_ca_df = sat19_ca_df.dropna()

# %%
sat19_ca_df.isnull().sum()
# Out:
# CDS                      0
# CCode                    0
# CDCode                   0
# SCode                    0
# RType                    0
# SName                    0
# DName                    0
# CName                    0
# Enroll12                 0
# NumTSTTakr12             0
# NumERWBenchmark12        0
# PctERWBenchmark12        0
# NumMathBenchmark12       0
# PctMathBenchmark12       0
# Enroll11                 0
# NumTSTTakr11             0
# NumERWBenchmark11        0
# PctERWBenchmark11        0
# NumMathBenchmark11       0
# PctMathBenchmark11       0
# TotNumBothBenchmark12    0
# PctBothBenchmark12       0
# TotNumBothBenchmark11    0
# PctBothBenchmark11       0
# Year                     0
# dtype: int64

# %%
sat19_ca_df.head()
# Out:
#             CDS  CCode     CDCode      SCode RType  \
# 2  1.964733e+13   19.0  1964733.0  1930924.0     S
# 3  1.964733e+13   19.0  1964733.0  1931476.0     S
# 5  1.964734e+13   19.0  1964733.0  6061451.0     S
# 6  3.073635e+13   30.0  3073635.0  3034956.0     S
# 9  1.964733e+13   19.0  1964733.0   119685.0     S
#
#                          SName                      DName        CName  \
# 2          Belmont Senior High        Los Angeles Unified  Los Angeles
# 3      Canoga Park Senior High        Los Angeles Unified  Los Angeles
# 5       Foshay Learning Center        Los Angeles Unified  Los Angeles
# 6           Mission Viejo High  Saddleback Valley Unified       Orange
# 9  New Open World Academy K-12        Los Angeles Unified  Los Angeles
#
#    Enroll12  NumTSTTakr12  ... NumTSTTakr11 NumERWBenchmark11  \
# 2     206.0         102.0  ...        174.0                42
# 3     227.0         113.0  ...        275.0                97
# ...

# %%
#anything that doesn't have an int or a float, will be flagged as an object

# %%
sat19_ca_df.isnull().sum()
# Out:
# CDS                      0
# CCode                    0
# CDCode                   0
# SCode                    0
# RType                    0
# SName                    0
# DName                    0
# CName                    0
# Enroll12                 0
# NumTSTTakr12             0
# NumERWBenchmark12        0
# PctERWBenchmark12        0
# NumMathBenchmark12       0
# PctMathBenchmark12       0
# Enroll11                 0
# NumTSTTakr11             0
# NumERWBenchmark11        0
# PctERWBenchmark11        0
# NumMathBenchmark11       0
# PctMathBenchmark11       0
# TotNumBothBenchmark12    0
# PctBothBenchmark12       0
# TotNumBothBenchmark11    0
# PctBothBenchmark11       0
# Year                     0
# dtype: int64

# %%
sat19_ca_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1199 entries, 2 to 2036
# Data columns (total 25 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   CDS                    1199 non-null   float64
#  1   CCode                  1199 non-null   float64
#  2   CDCode                 1199 non-null   float64
#  3   SCode                  1199 non-null   float64
#  4   RType                  1199 non-null   object
#  5   SName                  1199 non-null   object
#  6   DName                  1199 non-null   object
#  7   CName                  1199 non-null   object
#  8   Enroll12               1199 non-null   float64
#  9   NumTSTTakr12           1199 non-null   float64
#  10  NumERWBenchmark12      1199 non-null   object
#  11  PctERWBenchmark12      1199 non-null   object
#  12  NumMathBenchmark12     1199 non-null   object
#  13  PctMathBenchmark12     1199 non-null   object
# ...

# %%
sat19_ca_df.head(50)
# Out:
#              CDS  CCode     CDCode      SCode RType  \
# 1   6.616061e+12    6.0   661606.0   634758.0     S
# 2   1.964733e+13   19.0  1964733.0  1930924.0     S
# 3   1.964733e+13   19.0  1964733.0  1931476.0     S
# 4   1.964733e+13   19.0  1964733.0  1931856.0     S
# 5   1.964734e+13   19.0  1964733.0  6061451.0     S
# 6   3.073635e+13   30.0  3073635.0  3034956.0     S
# 8   1.363107e+13   13.0  1363107.0  1332501.0     S
# 9   1.964733e+13   19.0  1964733.0   119685.0     S
# 10  3.367033e+13   33.0  3367033.0  3331600.0     S
# 13  1.964634e+13   19.0  1964634.0  1996586.0     S
# 14  1.964733e+13   19.0  1964733.0  1930387.0     S
# 15  3.367181e+13   33.0  3367181.0  3335759.0     S
# 16  3.675051e+13   36.0  3675051.0  3630563.0     S
# 17  3.675077e+13   36.0  3675077.0  3630423.0     S
# 18  3.768339e+13   37.0  3768338.0  6061964.0     S
# 20  1.062117e+13   10.0  1062117.0  1030683.0     S
# 21  3.367090e+13   33.0  3367090.0   127720.0     S
# ...

# %%
sat19_ca_df.rename(columns={
    'CCode': 'county_code',
    'CDCode': 'cdc_code',
    'SCode': 'school_code',
    'RType': 'rtype',
    'SName': 'school_name',
    'CName': 'county',
}, inplace = True)

# %%
sat19_ca_df.rename(columns={
    'DName' : 'district_name',
    'Enroll12': 'enroll_12'
}, inplace = True)

# %%
sat19_ca_df.head(50)
# Out:
#              CDS  county_code   cdc_code  school_code rtype  \
# 1   6.616061e+12          6.0   661606.0     634758.0     S
# 2   1.964733e+13         19.0  1964733.0    1930924.0     S
# 3   1.964733e+13         19.0  1964733.0    1931476.0     S
# 4   1.964733e+13         19.0  1964733.0    1931856.0     S
# 5   1.964734e+13         19.0  1964733.0    6061451.0     S
# 6   3.073635e+13         30.0  3073635.0    3034956.0     S
# 8   1.363107e+13         13.0  1363107.0    1332501.0     S
# 9   1.964733e+13         19.0  1964733.0     119685.0     S
# 10  3.367033e+13         33.0  3367033.0    3331600.0     S
# 13  1.964634e+13         19.0  1964634.0    1996586.0     S
# 14  1.964733e+13         19.0  1964733.0    1930387.0     S
# 15  3.367181e+13         33.0  3367181.0    3335759.0     S
# 16  3.675051e+13         36.0  3675051.0    3630563.0     S
# 17  3.675077e+13         36.0  3675077.0    3630423.0     S
# 18  3.768339e+13         37.0  3768338.0    6061964.0     S
# ...

# %%
sat19_ca_df.head(50)
# Out:
#              CDS  county_code   cdc_code  school_code rtype  \
# 2   1.964733e+13         19.0  1964733.0    1930924.0     S
# 3   1.964733e+13         19.0  1964733.0    1931476.0     S
# 5   1.964734e+13         19.0  1964733.0    6061451.0     S
# 6   3.073635e+13         30.0  3073635.0    3034956.0     S
# 9   1.964733e+13         19.0  1964733.0     119685.0     S
# 10  3.367033e+13         33.0  3367033.0    3331600.0     S
# 13  1.964634e+13         19.0  1964634.0    1996586.0     S
# 15  3.367181e+13         33.0  3367181.0    3335759.0     S
# 17  3.675077e+13         36.0  3675077.0    3630423.0     S
# 18  3.768339e+13         37.0  3768338.0    6061964.0     S
# 20  1.062117e+13         10.0  1062117.0    1030683.0     S
# 22  3.968676e+13         39.0  3968676.0     108159.0     S
# 23  1.964733e+13         19.0  1964733.0    1938885.0     S
# 24  1.964733e+13         19.0  1964733.0    1996115.0     S
# 25  1.975664e+13         19.0  1975663.0    6120158.0     S
# ...

# %%
sat19_ca_df.drop(columns = 'CDS', inplace = True)

# %%
sat19_ca_df.isnull().sum()
# Out:
# county_code              0
# cdc_code                 0
# school_code              0
# rtype                    0
# school_name              0
# district_name            0
# county                   0
# enroll_12                0
# NumTSTTakr12             0
# NumERWBenchmark12        0
# PctERWBenchmark12        0
# NumMathBenchmark12       0
# PctMathBenchmark12       0
# Enroll11                 0
# NumTSTTakr11             0
# NumERWBenchmark11        0
# PctERWBenchmark11        0
# NumMathBenchmark11       0
# PctMathBenchmark11       0
# TotNumBothBenchmark12    0
# PctBothBenchmark12       0
# TotNumBothBenchmark11    0
# PctBothBenchmark11       0
# Year                     0
# dtype: int64

# %%
sat19_ca_df.head(50)
# Out:
#     county_code   cdc_code  school_code rtype  \
# 2          19.0  1964733.0    1930924.0     S
# 3          19.0  1964733.0    1931476.0     S
# 5          19.0  1964733.0    6061451.0     S
# 6          30.0  3073635.0    3034956.0     S
# 9          19.0  1964733.0     119685.0     S
# 10         33.0  3367033.0    3331600.0     S
# 13         19.0  1964634.0    1996586.0     S
# 15         33.0  3367181.0    3335759.0     S
# 17         36.0  3675077.0    3630423.0     S
# 18         37.0  3768338.0    6061964.0     S
# 20         10.0  1062117.0    1030683.0     S
# 22         39.0  3968676.0     108159.0     S
# 23         19.0  1964733.0    1938885.0     S
# 24         19.0  1964733.0    1996115.0     S
# 25         19.0  1975663.0    6120158.0     S
# 26         19.0  1975713.0    1934553.0     S
# 27         29.0  2966357.0    2935500.0     S
# 28         30.0  3073650.0    3035102.0     S
# 29         41.0  4168924.0    4137790.0     S
# ...

# %%
sat19_ca_df.rename(columns={
    'NumTSTTakr12' : 'num_of_senior_test_takers'
}, inplace = True)

# %%
sat19_ca_df.rename(columns={
    'NumERWBenchmark12' : '12th_grade_english_benchmark_passed',
    'PctERWBenchmark12' : '12th_grade_english_benchmark_percent',
    'NumMathBenchmark12' : '12th_grade_math_benchmark_passed',
    'Enroll11' : '11th_graders_enrolled',
    'NumTSTTakr11' : '11th_grade_test_takers',
    'NumERWBenchmark11' : '11th_grade_english_benchmark_passed',
    'PctERWBenchmark11' : '11th_grade_english_benchmark_percent',
    'NumMathBenchmark11' : '11th_grade_math_benchmark_passed',
    'PctMathBenchmark11' : '11th_grade_math_benchmark_percent',
    'TotNumBothBenchmark12' : 'total_12th_graders_passed',
    'PctBothBenchmark12' : 'total_12_graders_passed_%',
    'TotNumBothBenchmark11' : 'total_11th_graders_passed',
    'PctBothBenchmark11' : 'total_11th_graders_passed_%',
}, inplace = True)

# %%
sat19_ca_df.rename(columns={
    'PctMathBenchmark12' : '12th_math_percent',
}, inplace = True)

# %%
def str_to_num(x):
    return (float(x)/100)

# %%
sat19_ca_df['12th_grade_english_benchmark_percent'].apply(str_to_num)
# Out:
# 2       0.3039
# 3       0.4779
# 5       0.6415
# 6       0.8474
# 9       0.2500
#          ...
# 1973    0.8519
# 1976    0.7222
# 1979    0.7845
# 1980    0.7250
# 2036    0.6836
# Name: 12th_grade_english_benchmark_percent, Length: 1199, dtype: float64

# %%
sat19_ca_df['12th_grade_english_benchmark_percent'].apply(str_to_num)
# Out:
# 2       0.3039
# 3       0.4779
# 5       0.6415
# 6       0.8474
# 9       0.2500
#          ...
# 1973    0.8519
# 1976    0.7222
# 1979    0.7845
# 1980    0.7250
# 2036    0.6836
# Name: 12th_grade_english_benchmark_percent, Length: 1199, dtype: float64

# %%
sat19_ca_df['12th_grade_english_benchmark_percent'].apply(str_to_num)
# Out:
# 2       0.3039
# 3       0.4779
# 5       0.6415
# 6       0.8474
# 9       0.2500
#          ...
# 1973    0.8519
# 1976    0.7222
# 1979    0.7845
# 1980    0.7250
# 2036    0.6836
# Name: 12th_grade_english_benchmark_percent, Length: 1199, dtype: float64

# %%
sat19_ca_df['12th_grade_english_benchmark_percent']
# Out:
# 2       30.39
# 3       47.79
# 5       64.15
# 6       84.74
# 9       25.00
#         ...
# 1973    85.19
# 1976    72.22
# 1979    78.45
# 1980    72.50
# 2036    68.36
# Name: 12th_grade_english_benchmark_percent, Length: 1199, dtype: object

# %%
sat19_ca_df['12th_math_percent'] = sat19_ca_df['12th_math_percent'].replace('*', 0)

# %%
sat19_ca_df['12th_math_percent']
# Out:
# 1            0
# 2        13.73
# 3        15.93
# 4            0
# 5        33.96
# 6        72.63
# 8        22.22
# 9         8.82
# 10       43.14
# 13       44.12
# 14           0
# 15       34.21
# 16           0
# 17       37.63
# 18       51.56
# 20       43.46
# 21           0
# 22       26.04
# 23       42.49
# 24       30.43
# 25       70.21
# 26       85.50
# 27       71.91
# 28       90.24
# 29       49.13
# 30       24.10
# 31           0
# 32       30.12
# 33       10.84
# 34       19.85
# 35           0
# 37       89.80
# 38       61.63
# 39       80.34
# 40           0
# 41       35.29
# 44       91.25
# 47       81.21
# 48       66.67
# 50       11.11
# 51       44.00
# 52       23.38
# 54       64.75
# 55        0.00
# 56       53.57
# 57           0
# 58       36.61
# 59       65.11
# 60        0.00
# 61       23.73
# 63       68.82
# 64        3.23
# 65       37.89
# 66       29.41
# 67       25.25
# 68       52.00
# 69           0
# 70       63.01
# ...

# %%
sat19_ca_df['12th_math_percent'].apply(str_to_num)
# Out:
# 1       0.0000
# 2       0.1373
# 3       0.1593
# 4       0.0000
# 5       0.3396
# 6       0.7263
# 8       0.2222
# 9       0.0882
# 10      0.4314
# 13      0.4412
# 14      0.0000
# 15      0.3421
# 16      0.0000
# 17      0.3763
# 18      0.5156
# 20      0.4346
# 21      0.0000
# 22      0.2604
# 23      0.4249
# 24      0.3043
# 25      0.7021
# 26      0.8550
# 27      0.7191
# 28      0.9024
# 29      0.4913
# 30      0.2410
# 31      0.0000
# 32      0.3012
# 33      0.1084
# 34      0.1985
# 35      0.0000
# 37      0.8980
# 38      0.6163
# 39      0.8034
# 40      0.0000
# 41      0.3529
# 44      0.9125
# 47      0.8121
# 48      0.6667
# 50      0.1111
# 51      0.4400
# 52      0.2338
# 54      0.6475
# 55      0.0000
# 56      0.5357
# 57      0.0000
# 58      0.3661
# 59      0.6511
# 60      0.0000
# 61      0.2373
# 63      0.6882
# 64      0.0323
# 65      0.3789
# 66      0.2941
# 67      0.2525
# 68      0.5200
# 69      0.0000
# 70      0.6301
# ...

# %%
sat19_ca_df['11th_grade_english_benchmark_percent'] = sat19_ca_df['11th_grade_english_benchmark_percent'].replace('*', 0)

# %%
sat19_ca_df['11th_grade_english_benchmark_percent'].apply(str_to_num)
# Out:
# 1       0.0000
# 2       0.2414
# 3       0.3527
# 4       0.0000
# 5       0.4973
# 6       0.9238
# 8       0.0000
# 9       0.2785
# 10      0.7619
# 13      0.5902
# 14      0.1111
# 15      0.6250
# 16      0.0000
# 17      0.7611
# 18      0.6754
# 20      0.8482
# 21      0.0000
# 22      0.5648
# 23      0.6159
# 24      0.5542
# 25      0.9512
# 26      0.9263
# 27      0.9326
# 28      0.9813
# 29      0.9459
# 30      0.8704
# 31      0.0000
# 32      0.4223
# 33      0.2408
# 34      0.3715
# 35      0.0000
# 37      0.9363
# 38      0.8036
# 39      0.9615
# 40      0.0000
# 41      0.8235
# 44      0.9912
# 47      0.9830
# 48      0.8824
# 50      0.6471
# 51      0.8205
# 52      0.7059
# 54      0.9099
# 55      0.1827
# 56      0.8261
# 57      0.6296
# 58      0.7071
# 59      0.8186
# 60      0.1026
# 61      0.4987
# 63      0.9490
# 64      0.4000
# 65      0.6875
# 66      0.0000
# 67      0.3773
# 68      0.8209
# 69      0.0000
# 70      0.8421
# ...

# %%
sat19_ca_df['11th_grade_math_benchmark_percent'] = sat19_ca_df['11th_grade_english_benchmark_percent'].replace('*', 0)

# %%
sat19_ca_df['11th_grade_math_benchmark_percent'].apply(str_to_num)
# Out:
# 1       0.0000
# 2       0.2414
# 3       0.3527
# 4       0.0000
# 5       0.4973
# 6       0.9238
# 8       0.0000
# 9       0.2785
# 10      0.7619
# 13      0.5902
# 14      0.1111
# 15      0.6250
# 16      0.0000
# 17      0.7611
# 18      0.6754
# 20      0.8482
# 21      0.0000
# 22      0.5648
# 23      0.6159
# 24      0.5542
# 25      0.9512
# 26      0.9263
# 27      0.9326
# 28      0.9813
# 29      0.9459
# 30      0.8704
# 31      0.0000
# 32      0.4223
# 33      0.2408
# 34      0.3715
# 35      0.0000
# 37      0.9363
# 38      0.8036
# 39      0.9615
# 40      0.0000
# 41      0.8235
# 44      0.9912
# 47      0.9830
# 48      0.8824
# 50      0.6471
# 51      0.8205
# 52      0.7059
# 54      0.9099
# 55      0.1827
# 56      0.8261
# 57      0.6296
# 58      0.7071
# 59      0.8186
# 60      0.1026
# 61      0.4987
# 63      0.9490
# 64      0.4000
# 65      0.6875
# 66      0.0000
# 67      0.3773
# 68      0.8209
# 69      0.0000
# 70      0.8421
# ...

# %%
sat19_ca_df['total_12_graders_passed_%'] = sat19_ca_df['total_12_graders_passed_%'].replace('*', 0)

# %%
sat19_ca_df['total_12_graders_passed_%'].apply(str_to_num)
# Out:
# 1       0.0000
# 2       0.1373
# 3       0.1593
# 4       0.0000
# 5       0.3396
# 6       0.6947
# 8       0.1852
# 9       0.0882
# 10      0.4020
# 13      0.4265
# 14      0.0000
# 15      0.3158
# 16      0.0000
# 17      0.3602
# 18      0.4375
# 20      0.3966
# 21      0.0000
# 22      0.2031
# 23      0.3938
# 24      0.3043
# 25      0.6809
# 26      0.7993
# 27      0.6966
# 28      0.8732
# 29      0.4448
# 30      0.2329
# 31      0.0000
# 32      0.2771
# 33      0.0964
# 34      0.1695
# 35      0.0000
# 37      0.8571
# 38      0.5930
# 39      0.7416
# 40      0.0000
# 41      0.3529
# 44      0.9102
# 47      0.7987
# 48      0.6667
# 50      0.0556
# 51      0.4400
# 52      0.2338
# 54      0.6393
# 55      0.0000
# 56      0.5357
# 57      0.0000
# 58      0.3214
# 59      0.6331
# 60      0.0000
# 61      0.2175
# 63      0.6654
# 64      0.0323
# 65      0.3579
# 66      0.2941
# 67      0.2277
# 68      0.4600
# 69      0.0000
# 70      0.5780
# ...

# %%
sat19_ca_df['total_11th_graders_passed_%'] = sat19_ca_df['total_11th_graders_passed_%'].replace('*', 0)

# %%
sat19_ca_df['total_11th_graders_passed_%']['total_11th_graders_passed_%'].apply(str_to_num)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2894             try:
# -> 2895                 return self._engine.get_loc(casted_key)
#    2896             except KeyError as err:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index_class_helper.pxi in pandas._libs.index.Int64Engine._check_type()
#
# KeyError: 'total_11th_graders_passed_%'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-50-ebb386bd5c27> in <module>
# ----> 1 sat19_ca_df['total_11th_graders_passed_%']['total_11th_graders_passed_%'].apply(str_to_num)
#
# ...

# %%
sat19_ca_df.head()
# Out:
#    county_code   cdc_code  school_code rtype              school_name  \
# 1          6.0   661606.0     634758.0     S          Maxwell Sr High
# 2         19.0  1964733.0    1930924.0     S      Belmont Senior High
# 3         19.0  1964733.0    1931476.0     S  Canoga Park Senior High
# 4         19.0  1964733.0    1931856.0     S     Whitman Continuation
# 5         19.0  1964733.0    6061451.0     S   Foshay Learning Center
#
#          district_name       county  enroll_12  num_of_senior_test_takers  \
# 1      Maxwell Unified       Colusa       29.0                       10.0
# 2  Los Angeles Unified  Los Angeles      206.0                      102.0
# 3  Los Angeles Unified  Los Angeles      227.0                      113.0
# 4  Los Angeles Unified  Los Angeles       18.0                       14.0
# 5  Los Angeles Unified  Los Angeles      166.0                      106.0
#
#   12th_grade_english_benchmark_passed 12th_grade_english_benchmark_percent  \
# ...

# %%
sat19_ca_df.replace('*', 0)
# Out:
#       county_code   cdc_code  school_code rtype  \
# 1             6.0   661606.0     634758.0     S
# 2            19.0  1964733.0    1930924.0     S
# 3            19.0  1964733.0    1931476.0     S
# 4            19.0  1964733.0    1931856.0     S
# 5            19.0  1964733.0    6061451.0     S
# 6            30.0  3073635.0    3034956.0     S
# 8            13.0  1363107.0    1332501.0     S
# 9            19.0  1964733.0     119685.0     S
# 10           33.0  3367033.0    3331600.0     S
# 13           19.0  1964634.0    1996586.0     S
# 14           19.0  1964733.0    1930387.0     S
# 15           33.0  3367181.0    3335759.0     S
# 16           36.0  3675051.0    3630563.0     S
# 17           36.0  3675077.0    3630423.0     S
# 18           37.0  3768338.0    6061964.0     S
# 20           10.0  1062117.0    1030683.0     S
# 21           33.0  3367090.0     127720.0     S
# 22           39.0  3968676.0     108159.0     S
# ...

# %%
sat19_ca_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1602 entries, 1 to 2036
# Data columns (total 24 columns):
#  #   Column                                Non-Null Count  Dtype
# ---  ------                                --------------  -----
#  0   county_code                           1602 non-null   float64
#  1   cdc_code                              1602 non-null   float64
#  2   school_code                           1602 non-null   float64
#  3   rtype                                 1602 non-null   object
#  4   school_name                           1602 non-null   object
#  5   district_name                         1602 non-null   object
#  6   county                                1602 non-null   object
#  7   enroll_12                             1602 non-null   float64
#  8   num_of_senior_test_takers             1602 non-null   float64
#  9   12th_grade_english_benchmark_passed   1602 non-null   object
#  10  12th_grade_english_benchmark_percent  1602 non-null   object
# ...

# %%
sat19_ca_df.head(10)
# Out:
#     CCode     CDCode      SCode RType                         SName  \
# 1     6.0   661606.0   634758.0     S               Maxwell Sr High
# 2    19.0  1964733.0  1930924.0     S           Belmont Senior High
# 3    19.0  1964733.0  1931476.0     S       Canoga Park Senior High
# 4    19.0  1964733.0  1931856.0     S          Whitman Continuation
# 5    19.0  1964733.0  6061451.0     S        Foshay Learning Center
# 6    30.0  3073635.0  3034956.0     S            Mission Viejo High
# 8    13.0  1363107.0  1332501.0     S               Calipatria High
# 9    19.0  1964733.0   119685.0     S   New Open World Academy K-12
# 10   33.0  3367033.0  3331600.0     S                   Corona High
# 13   19.0  1964634.0  1996586.0     S  Animo Inglewood Charter High
#
#                         DName        CName  Enroll12  \
# 1             Maxwell Unified       Colusa      29.0
# 2         Los Angeles Unified  Los Angeles     206.0
# 3         Los Angeles Unified  Los Angeles     227.0
# ...

# %%
sat19_ca_df.head(10)
# Out:
#     CCode     CDCode      SCode RType                         SName  \
# 1     6.0   661606.0   634758.0     S               Maxwell Sr High
# 2    19.0  1964733.0  1930924.0     S           Belmont Senior High
# 3    19.0  1964733.0  1931476.0     S       Canoga Park Senior High
# 4    19.0  1964733.0  1931856.0     S          Whitman Continuation
# 5    19.0  1964733.0  6061451.0     S        Foshay Learning Center
# 6    30.0  3073635.0  3034956.0     S            Mission Viejo High
# 8    13.0  1363107.0  1332501.0     S               Calipatria High
# 9    19.0  1964733.0   119685.0     S   New Open World Academy K-12
# 10   33.0  3367033.0  3331600.0     S                   Corona High
# 13   19.0  1964634.0  1996586.0     S  Animo Inglewood Charter High
#
#                         DName        CName  Enroll12  \
# 1             Maxwell Unified       Colusa      29.0
# 2         Los Angeles Unified  Los Angeles     206.0
# 3         Los Angeles Unified  Los Angeles     227.0
# ...

# %%
sat19_ca_df = sat19_ca_df.replace('*', 0)

# %%
sat19_ca_df.head()
# Out:
#    CCode     CDCode      SCode RType                    SName  \
# 1    6.0   661606.0   634758.0     S          Maxwell Sr High
# 2   19.0  1964733.0  1930924.0     S      Belmont Senior High
# 3   19.0  1964733.0  1931476.0     S  Canoga Park Senior High
# 4   19.0  1964733.0  1931856.0     S     Whitman Continuation
# 5   19.0  1964733.0  6061451.0     S   Foshay Learning Center
#
#                  DName        CName  Enroll12  num_of_senior_test_takers  \
# 1      Maxwell Unified       Colusa      29.0                       10.0
# 2  Los Angeles Unified  Los Angeles     206.0                      102.0
# 3  Los Angeles Unified  Los Angeles     227.0                      113.0
# 4  Los Angeles Unified  Los Angeles      18.0                       14.0
# 5  Los Angeles Unified  Los Angeles     166.0                      106.0
#
#   12th_grade_english_benchmark_passed 12th_grade_english_benchmark_percent  \
# ...

# %%
sat19_ca_df['12th_grade_english_benchmark_passed'] = sat19_ca_df['12th_grade_english_benchmark_passed'].fillna('0')

# %%
sat19_ca_df.head()
# Out:
#    CCode     CDCode      SCode RType                    SName  \
# 1    6.0   661606.0   634758.0     S          Maxwell Sr High
# 2   19.0  1964733.0  1930924.0     S      Belmont Senior High
# 3   19.0  1964733.0  1931476.0     S  Canoga Park Senior High
# 4   19.0  1964733.0  1931856.0     S     Whitman Continuation
# 5   19.0  1964733.0  6061451.0     S   Foshay Learning Center
#
#                  DName        CName  Enroll12  num_of_senior_test_takers  \
# 1      Maxwell Unified       Colusa      29.0                       10.0
# 2  Los Angeles Unified  Los Angeles     206.0                      102.0
# 3  Los Angeles Unified  Los Angeles     227.0                      113.0
# 4  Los Angeles Unified  Los Angeles      18.0                       14.0
# 5  Los Angeles Unified  Los Angeles     166.0                      106.0
#
#   12th_grade_english_benchmark_passed 12th_grade_english_benchmark_percent  \
# ...

# %%
sat19_ca_df = sat19_ca_df.fillna('0')

# %%
sat19_ca_df.head(10)
# Out:
#     CCode     CDCode      SCode RType                         SName  \
# 1     6.0   661606.0   634758.0     S               Maxwell Sr High
# 2    19.0  1964733.0  1930924.0     S           Belmont Senior High
# 3    19.0  1964733.0  1931476.0     S       Canoga Park Senior High
# 4    19.0  1964733.0  1931856.0     S          Whitman Continuation
# 5    19.0  1964733.0  6061451.0     S        Foshay Learning Center
# 6    30.0  3073635.0  3034956.0     S            Mission Viejo High
# 8    13.0  1363107.0  1332501.0     S               Calipatria High
# 9    19.0  1964733.0   119685.0     S   New Open World Academy K-12
# 10   33.0  3367033.0  3331600.0     S                   Corona High
# 13   19.0  1964634.0  1996586.0     S  Animo Inglewood Charter High
#
#                         DName        CName  Enroll12  \
# 1             Maxwell Unified       Colusa      29.0
# 2         Los Angeles Unified  Los Angeles     206.0
# 3         Los Angeles Unified  Los Angeles     227.0
# ...

# %%
sat19_ca_df_update = sat19_ca_df

# %%
sat19_ca_df_update.to_csv('updated_sat19_ca.csv', index = False)

# %%
sat19_ca_df.dtypes
# Out:
# county_code                             float64
# cdc_code                                float64
# school_code                             float64
# rtype                                    object
# school_name                              object
# district_name                            object
# county                                   object
# enroll_12                               float64
# num_of_senior_test_takers               float64
# 12th_grade_english_benchmark_passed      object
# 12th_grade_english_benchmark_percent     object
# 12th_grade_math_benchmark_passed         object
# 12th_math_percent                        object
# 11th_graders_enrolled                   float64
# 11th_grade_test_takers                  float64
# 11th_grade_english_benchmark_passed      object
# 11th_grade_english_benchmark_percent     object
# 11th_grade_math_benchmark_passed         object
# 11th_grade_math_benchmark_percent        object
# total_12th_graders_passed                object
# ...

# %%
sat19_ca_df['12th_grade_english_benchmark_passed'] = sat19_ca_df['12th_grade_english_benchmark_passed'].map(lambda x: np.nan if x =='*' else int(x))

# %%
sat19_ca_df['12th_grade_english_benchmark_percent'] = sat19_ca_df['12th_grade_english_benchmark_percent'].map(lambda x: np.nan if x =='*' else float(x))

# %%
sat19_ca_df['12th_grade_math_benchmark_passed'] = sat19_ca_df['12th_grade_math_benchmark_passed'].map(lambda x: np.nan if x =='*' else int(x))

# %%
sat19_ca_df['11th_grade_english_benchmark_passed'] = sat19_ca_df['11th_grade_english_benchmark_passed'].map(lambda x: np.nan if x =='*' else float(x))

# %%
sat19_ca_df['11th_grade_english_benchmark_percent'] = sat19_ca_df['11th_grade_english_benchmark_percent'].map(lambda x: np.nan if x =='*' else float(x))

# %%
sat19_ca_df['11th_grade_math_benchmark_passed'] = sat19_ca_df['11th_grade_math_benchmark_passed'].map(lambda x: np.nan if x =='*' else float(x))

# %%
sat19_ca_df['11th_grade_math_benchmark_percent'] = sat19_ca_df['11th_grade_math_benchmark_percent'].map(lambda x: np.nan if x =='*' else float(x))

# %%
sat19_ca_df['total_12th_graders_passed'] = sat19_ca_df['total_12th_graders_passed'].map(lambda x: np.nan if x =='*' else float(x))

# %%
sat19_ca_df['total_12_graders_passed_%'] = sat19_ca_df['total_12_graders_passed_%'].map(lambda x: np.nan if x =='*' else float(x))

# %%
sat19_ca_df['total_11th_graders_passed'] = sat19_ca_df['total_11th_graders_passed'].map(lambda x: np.nan if x =='*' else float(x))

# %%
sat19_ca_df['total_11th_graders_passed_%'] = sat19_ca_df['total_11th_graders_passed_%'].map(lambda x: np.nan if x =='*' else float(x))

# %%
sat19_ca_df.dtypes
# Out:
# county_code                             float64
# cdc_code                                float64
# school_code                             float64
# rtype                                    object
# school_name                              object
# district_name                            object
# county                                   object
# enroll_12                               float64
# num_of_senior_test_takers               float64
# 12th_grade_english_benchmark_passed       int64
# 12th_grade_english_benchmark_percent    float64
# 12th_grade_math_benchmark_passed          int64
# 12th_math_percent                       float64
# 11th_graders_enrolled                   float64
# 11th_grade_test_takers                  float64
# 11th_grade_english_benchmark_passed     float64
# 11th_grade_english_benchmark_percent    float64
# 11th_grade_math_benchmark_passed        float64
# 11th_grade_math_benchmark_percent       float64
# total_12th_graders_passed               float64
# ...

# %%
sat19_ca_df_updated2 = sat19_ca_df

# %%
sat19_ca_df['12th_math_percent'] = sat19_ca_df['12th_math_percent'].map(lambda x: np.nan if x =='*' else float(x))

# %%
sat19_ca_df.head(10)
# Out:
#     county_code   cdc_code  school_code rtype                   school_name  \
# 2          19.0  1964733.0    1930924.0     S           Belmont Senior High
# 3          19.0  1964733.0    1931476.0     S       Canoga Park Senior High
# 5          19.0  1964733.0    6061451.0     S        Foshay Learning Center
# 6          30.0  3073635.0    3034956.0     S            Mission Viejo High
# 9          19.0  1964733.0     119685.0     S   New Open World Academy K-12
# 10         33.0  3367033.0    3331600.0     S                   Corona High
# 13         19.0  1964634.0    1996586.0     S  Animo Inglewood Charter High
# 15         33.0  3367181.0    3335759.0     S               Palo Verde High
# 17         36.0  3675077.0    3630423.0     S             Apple Valley High
# 18         37.0  3768338.0    6061964.0     S         The O'Farrell Charter
#
#                 district_name          county  enroll_12  \
# 2         Los Angeles Unified     Los Angeles      206.0
# ...

# %%
sat19_ca_df.shape
# Out:
# (1199, 24)

# %%
sat19_ca_df.to_csv('sat19_ca_df_cleaned_final', index = False)
