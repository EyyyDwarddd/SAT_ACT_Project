# %%
import pandas as pd
import numpy as np #pandas is built on top of numpy. numpy used as a DA/computation tool
import matplotlib.pyplot as plt
import seaborn as sns

# %%
pd.set_option('display.max_rows', None, 'display.max_colwidth', None)

# %%
act19_ca_df = pd.read_csv('/Users/edwardmendoza/Documents/GA/project_1/data/act_2019_ca.csv')

# %% [markdown]
# Display the data: print the first 5 rows of each dataframe to your Jupyter notebook.

# %%
act19_ca_df.head()
# Out:
#             CDS  CCode     CDCode      SCode RType  \
# 3  4.369666e+13   43.0  4369666.0  4333795.0     S
# 4  1.964733e+13   19.0  1964733.0  1935121.0     S
# 5  1.976968e+13   19.0  1976968.0   109926.0     S
# 6  1.964733e+13   19.0  1964733.0   126615.0     S
# 7  1.964246e+13   19.0  1964246.0   126003.0     S
#
#                                                    SName  \
# 3                                   Abraham Lincoln High
# 4                            Abraham Lincoln Senior High
# 5                                Academia Avance Charter
# 6  Academies of Education and Empowerment at Carson High
# 7                       Academies of the Antelope Valley
#
#                            DName        CName  Enroll12  NumTstTakr  \
# 3               San Jose Unified  Santa Clara     463.0        53.0
# 4            Los Angeles Unified  Los Angeles     226.0        19.0
# 5  SBE - Academia Avance Charter  Los Angeles      65.0        33.0
# ...

# %% [markdown]
# Check for missing values.

# %%
act19_ca_df.drop(columns = ['Unnamed: 17'], inplace = True)

# %%
act19_ca_df.isnull().sum()
# Out:
# CDS             1
# CCode           1
# CDCode          1
# SCode         523
# RType           1
# SName         581
# DName          59
# CName           1
# Enroll12        1
# NumTstTakr      1
# AvgScrRead    357
# AvgScrEng     357
# AvgScrMath    357
# AvgScrSci     357
# NumGE21       357
# PctGE21       357
# Year            1
# dtype: int64

# %%
act19_ca_df.replace("*", np.nan)
# Out:
#                CDS  CCode     CDCode      SCode RType  \
# 0     3.366993e+13   33.0  3366993.0   129882.0     S
# 1     1.964212e+13   19.0  1964212.0  1995596.0     S
# 2     1.563776e+13   15.0  1563776.0  1530377.0     S
# 3     4.369666e+13   43.0  4369666.0  4333795.0     S
# 4     1.964733e+13   19.0  1964733.0  1935121.0     S
# 5     1.976968e+13   19.0  1976968.0   109926.0     S
# 6     1.964733e+13   19.0  1964733.0   126615.0     S
# 7     1.964246e+13   19.0  1964246.0   126003.0     S
# 8     3.868478e+13   38.0  3868478.0   119958.0     S
# 9     3.675077e+13   36.0  3675077.0  3631207.0     S
# 10    1.964733e+13   19.0  1964733.0   126573.0     S
# 11    3.667736e+13   36.0  3667736.0   116723.0     S
# 12    1.964733e+13   19.0  1964733.0   126623.0     S
# 13    1.965136e+13   19.0  1965136.0  1996321.0     S
# 14    1.262810e+13   12.0  1262810.0   108688.0     S
# 15    7.616300e+12    7.0   761630.0   107524.0     S
# ...

# %%
act19_ca_df.shape
# Out:
# (2310, 17)

# %%
act19_ca_df = act19_ca_df.dropna()

# %%
act19_ca_df.isnull().sum()

# %%
act19_ca_df.head()
# Out:
#             CDS  CCode     CDCode      SCode RType  \
# 3  4.369666e+13   43.0  4369666.0  4333795.0     S
# 4  1.964733e+13   19.0  1964733.0  1935121.0     S
# 5  1.976968e+13   19.0  1976968.0   109926.0     S
# 6  1.964733e+13   19.0  1964733.0   126615.0     S
# 7  1.964246e+13   19.0  1964246.0   126003.0     S
#
#                                                    SName  \
# 3                                   Abraham Lincoln High
# 4                            Abraham Lincoln Senior High
# 5                                Academia Avance Charter
# 6  Academies of Education and Empowerment at Carson High
# 7                       Academies of the Antelope Valley
#
#                            DName        CName  Enroll12  NumTstTakr  \
# 3               San Jose Unified  Santa Clara     463.0        53.0
# 4            Los Angeles Unified  Los Angeles     226.0        19.0
# 5  SBE - Academia Avance Charter  Los Angeles      65.0        33.0
# ...

# %%
act19_ca_df = act19_ca_df.replace("*", np.nan)

# %%
act19_ca_df.head()
# Out:
#             CDS  CCode     CDCode      SCode RType  \
# 3  4.369666e+13   43.0  4369666.0  4333795.0     S
# 4  1.964733e+13   19.0  1964733.0  1935121.0     S
# 5  1.976968e+13   19.0  1976968.0   109926.0     S
# 6  1.964733e+13   19.0  1964733.0   126615.0     S
# 7  1.964246e+13   19.0  1964246.0   126003.0     S
#
#                                                    SName  \
# 3                                   Abraham Lincoln High
# 4                            Abraham Lincoln Senior High
# 5                                Academia Avance Charter
# 6  Academies of Education and Empowerment at Carson High
# 7                       Academies of the Antelope Valley
#
#                            DName        CName  Enroll12  NumTstTakr  \
# 3               San Jose Unified  Santa Clara     463.0        53.0
# 4            Los Angeles Unified  Los Angeles     226.0        19.0
# 5  SBE - Academia Avance Charter  Los Angeles      65.0        33.0
# ...

# %%
act19_ca_df = act19_ca_df.dropna()

# %%
act19_ca_df.isnull().sum()
# Out:
# cds                   0
# county_code           0
# cdc_code              0
# school_code           0
# rtype                 0
# school_name           0
# district_name         0
# county_name           0
# students_enrolled     0
# num_of_test_takers    0
# avg_reading_score     0
# avg_english_score     0
# avg_math_score        0
# avg_science_score     0
# scores_over_20        0
# pct_scores_over_20    0
# Year                  0
# dtype: int64

# %%
act19_ca_df.rename(columns={
    'CDS' : 'cds',
    'CCode': 'county_code',
    'CDCode': 'cdc_code',
    'SCode': 'school_code',
    'RType': 'rtype',
    'SName': 'school_name',
    'CName': 'county',
    'DName': 'district_name',
    'CName' : 'county_name',
    'Enroll12' : 'students_enrolled',
    'NumTstTakr' : 'num_of_test_takers',
    'AvgScrRead' : 'avg_reading_score',
    'AvgScrEng' : 'avg_english_score',
    'AvgScrMath' : 'avg_math_score',
    'AvgScrSci' : 'avg_science_score',
    'NumGE21' : 'scores_over_20',
    'PctGE21' : 'pct_scores_over_20'
}, inplace = True)

# %%
def str_to_num(x):
    return (float(x)/100)

# %%
act19_ca_df['pct_scores_over_20'].value_counts()
# Out:
# 50.00     17
# 0.00       8
# 33.33      8
# 66.67      7
# 28.57      7
# 36.84      6
# 40.00      6
# 62.50      6
# 77.78      5
# 38.89      5
# 9.09       5
# 75.00      5
# 25.00      5
# 31.25      5
# 69.05      5
# 60.00      5
# 60.87      5
# 71.43      4
# 85.71      4
# 68.18      4
# 87.50      4
# 57.89      4
# 25.71      4
# 11.76      4
# 47.37      4
# 22.22      4
# 65.00      4
# 17.39      4
# 52.63      4
# 31.82      4
# 36.36      4
# 48.39      4
# 70.00      4
# 7.69       4
# 81.82      4
# 12.50      3
# 37.04      3
# 55.56      3
# 100.00     3
# 83.33      3
# 72.22      3
# 56.76      3
# 12.12      3
# 73.08      3
# 11.11      3
# 80.00      3
# 23.33      3
# 42.31      3
# 52.94      3
# 20.59      3
# 20.00      3
# 64.71      3
# 10.00      3
# 63.64      3
# 31.48      3
# 57.14      3
# 43.75      3
# 54.17      3
# 65.79      3
# 30.77      3
# 27.78      3
# 46.15      3
# 18.18      3
# 69.57      3
# 86.67      3
# 53.85      2
# ...

# %%
act19_ca_df['pct_scores_over_20'] = act19_ca_df['pct_scores_over_20'].apply(str_to_num)

# %%
act19_ca_df_update = act19_ca_df

# %%
act19_ca_df.head(50)
# Out:
#              cds  county_code   cdc_code  school_code rtype  \
# 3   4.369666e+13         43.0  4369666.0    4333795.0     S
# 4   1.964733e+13         19.0  1964733.0    1935121.0     S
# 5   1.976968e+13         19.0  1976968.0     109926.0     S
# 6   1.964733e+13         19.0  1964733.0     126615.0     S
# 13  1.965136e+13         19.0  1965136.0    1996321.0     S
# 16  7.616301e+12          7.0   761630.0     730283.0     S
# 18  4.369427e+13         43.0  4369427.0     125617.0     S
# 19  3.667934e+13         36.0  3667934.0     125419.0     S
# 20  5.672547e+13         56.0  5672546.0    5631619.0     S
# 21  4.369674e+13         43.0  4369674.0    4338802.0     S
# 22  1.964683e+13         19.0  1964683.0    1930080.0     S
# 23  1.964733e+13         19.0  1964733.0     118588.0     S
# 25  1.611190e+12          1.0   161119.0     130229.0     S
# 27  1.611270e+12          1.0   161127.0     130450.0     S
# 29  1.964733e+13         19.0  1964733.0    1933852.0     S
# ...

# %%
type(act19_ca_df)
# Out:
# pandas.core.frame.DataFrame

# %%
act19_ca_df.dtypes
# Out:
# cds                   float64
# county_code           float64
# cdc_code              float64
# school_code           float64
# rtype                  object
# school_name            object
# district_name          object
# county_name            object
# students_enrolled     float64
# num_of_test_takers    float64
# avg_reading_score      object
# avg_english_score      object
# avg_math_score         object
# avg_science_score      object
# scores_over_20         object
# pct_scores_over_20    float64
# Year                   object
# dtype: object

# %%
act19_ca_df['scores_over_20'].describe()
# Out:
# count     2310
# unique     279
# top          *
# freq       532
# Name: scores_over_20, dtype: object

# %%
act19_ca_df['scores_over_20'].dtype
# Out:
# dtype('O')

# %%
act19_ca_df['scores_over_20'] = act19_ca_df['scores_over_20'].map(lambda x: np.nan if x =='*' else int(x))

# %%
act19_ca_df['scores_over_20'].dtype
# Out:
# dtype('int64')

# %%
act19_ca_df['scores_over_20'].describe()
# Out:
# count     1017.000000
# mean        88.336283
# std       1425.204738
# min          0.000000
# 25%         12.000000
# 50%         24.000000
# 75%         55.000000
# max      45466.000000
# Name: scores_over_20, dtype: float64

# %%
act19_ca_df['students_enrolled'] = act19_ca_df['students_enrolled'].map(lambda x: np.nan if x =='*' else int(x))

# %%
act19_ca_df['students_enrolled'].dtype
# Out:
# dtype('int64')

# %%
act19_ca_df['num_of_test_takers'] = act19_ca_df['num_of_test_takers'].map(lambda x: np.nan if x =='*' else int(x))

# %%
act19_ca_df['avg_reading_score'] = act19_ca_df['avg_reading_score'].map(lambda x: np.nan if x =='*' else int(x))

# %%
act19_ca_df['avg_english_score'] = act19_ca_df['avg_english_score'].map(lambda x: np.nan if x =='*' else int(x))

# %%
act19_ca_df['avg_math_score'] = act19_ca_df['avg_math_score'].map(lambda x: np.nan if x =='*' else int(x))

# %%
act19_ca_df['avg_science_score'] = act19_ca_df['avg_science_score'].map(lambda x: np.nan if x =='*' else int(x))

# %%
act19_ca_df['pct_scores_over_20'] = act19_ca_df['pct_scores_over_20'].map(lambda x: np.nan if x =='*' else float(x))

# %%
act19_ca_df.dtypes
# Out:
# cds                   float64
# county_code           float64
# cdc_code              float64
# school_code           float64
# rtype                  object
# school_name            object
# district_name          object
# county_name            object
# students_enrolled     float64
# num_of_test_takers    float64
# avg_reading_score      object
# avg_english_score      object
# avg_math_score         object
# avg_science_score      object
# scores_over_20          int64
# pct_scores_over_20    float64
# Year                   object
# dtype: object

# %%
act19_ca_df_updated2 = act19_ca_df

# %%
act19_ca_df_updated2.to_csv('act19_ca_df_cleaned2', index = False)

# %%
act19_ca_df.to_csv('act19_ca_df_final_cleaned', index = False)
